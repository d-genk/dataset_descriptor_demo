# %%
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv('data.csv')

# Show the first few rows to get a sense of what the data looks like
df.head()
# Out:
#   colum_1 column_2
# 0  data_1   data_2
